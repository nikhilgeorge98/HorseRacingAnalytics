# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel (r'C:\Users\Nikhil\Desktop\BANGALORE DATA FILE.xlsx')

# %%
pd.set_option('display.max_columns', 30)

# %%
df.head(10)
# Out:
#    H.No    Date  Season  NoR  SRDN  Race No  Pl              Horse  \
# 0     1  181102  BW1819    6     1        1   7        INKY BLACK
# 1     2  181102  BW1819    6     1        1   4       SHEER MAGIC
# 2     3  181102  BW1819    6     1        1   3       DESERT GILT
# 3     4  181102  BW1819    6     1        1   5            PURITY
# 4     5  181102  BW1819    6     1        1   2      TUDOR PRINCE
# 5     6  181102  BW1819    6     1        1   8     RACY PRINCESS
# 6     7  181102  BW1819    6     1        1   9          KANTHAKA
# 7     8  181102  BW1819    6     1        1   1      HUNTERS MOON
# 8     9  181102  BW1819    6     1        1  10  PREMIER PREMISES
# 9    10  181102  BW1819    6     1        1   6        GREY HOUND
#
#                                        Pedigree       Desc  \
# 0  Mull Of Kintyre(USA)-Isabellas Treasure(IRE)  4y dk b m
# 1     Burden Of Proof(IRE)-Ripple Of Pride(IRE)     4y b m
# ...

# %%
df['Horse']
# Out:
# 0               INKY BLACK
# 1              SHEER MAGIC
# 2              DESERT GILT
# 3                   PURITY
# 4             TUDOR PRINCE
#                ...
# 2184                CAMILA
# 2185               GRANADA
# 2186     GREAT CELEBRATION
# 2187    EXTREMELYDANGEROUS
# 2188       JE NE SAIS QUOI
# Name: Horse, Length: 2189, dtype: object

# %%
df[['Horse', 'Desc']]
# Out:
#                     Horse       Desc
# 0             INKY BLACK   4y dk b m
# 1            SHEER MAGIC      4y b m
# 2            DESERT GILT      6y b g
# 3                 PURITY   4y dk b m
# 4           TUDOR PRINCE      5y b g
# ...                   ...        ...
# 2184              CAMILA      4y b f
# 2185             GRANADA      7y b g
# 2186   GREAT CELEBRATION      4y b g
# 2187  EXTREMELYDANGEROUS      7y b m
# 2188     JE NE SAIS QUOI      4y b g
#
# [2189 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['H.No', 'Date', 'Season', 'NoR', 'SRDN', 'Race No', 'Pl', 'Horse',
#        'Pedigree', 'Desc', 'Trainer', 'Jockey', 'Wt', 'Al', 'Dr', 'Sh',
#        'Won By', 'Dist Win', 'Rtg', 'Odds', 'Time', 'Cup', 'Classification',
#        'Distance', 'Unnamed: 24'],
#       dtype='object')

# %%
df['Jockey']
# Out:
# 0          Arshad Alam
# 1             Md Akram
# 2         Antony Raj S
# 3       Mudassar Nazar
# 4         A Imran Khan
#              ...
# 2184         P P Dhebe
# 2185          R Manish
# 2186           K Nazil
# 2187            P Mani
# 2188       Irvan Singh
# Name: Jockey, Length: 2189, dtype: object

# %%
df['Jockey'].value_counts()
# Out:
# Arshad Alam     103
# P Trevor        101
# R N Darshan      98
# T S Jodha        86
# A Sandesh        74
#                ...
# B Nayak           2
# R Ajay Kumar      2
# S K Paswan        2
# Shobhan Babu      1
# M D Praveen       1
# Name: Jockey, Length: 78, dtype: int64

# %%
df['Trainer']
# Out:
# 0              K P G Appu
# 1               Azhar Ali
# 2            F Sirajuddin
# 3       Arjun Mangalorkar
# 4       Aravind Ganapathy
#               ...
# 2184        Neil Darashah
# 2185         Mahmood Khan
# 2186            Azhar Ali
# 2187         Warren Singh
# 2188       Darius Byramji
# Name: Trainer, Length: 2189, dtype: object

# %%
df['Cup'].value_counts()
# Out:
# The T.B.Hanumantharaj Memorial Trophy Div-1    23
# The Mysore Race Club Trophy                    14
# The Beloved Prince Plate                       14
# The Mount Joy Plate Div-2                      14
# The Mount Joy Plate Div-1                      14
#                                                ..
# The Ashoka Chakra Cup                           6
# The Melkote Plate                               6
# The Bangalore Juvenile Million (Gr.3)           5
# The Stayers Trial Stakes                        4
# The Chief Minister's Trophy                     4
# Name: Cup, Length: 201, dtype: int64

# %%
filt = df['Cup']=='The Kunigal Stud Plate'

# %%
df.loc[filt]
# Out:
#      H.No    Date  Season  NoR  SRDN  Race No  Pl              Horse  \
# 742     1  181215  BW1819    6    10        5  11         NIKANDROS
# 743     2  181215  BW1819    6    10        5   8              MINT
# 744     3  181215  BW1819    6    10        5   W           TORSORO
# 745     4  181215  BW1819    6    10        5   2     HAEDI'S FOLLY
# 746     5  181215  BW1819    6    10        5   1         LOUISIANA
# 747     6  181215  BW1819    6    10        5  10      MINIVER ROSE
# 748     7  181215  BW1819    6    10        5   5              TZAR
# 749     8  181215  BW1819    6    10        5  13     SHAN BEN AARI
# 750     9  181215  BW1819    6    10        5   3            AEISIR
# 751    10  181215  BW1819    6    10        5   9    EXPORT QUALITY
# 752    11  181215  BW1819    6    10        5  12  SILVER CHIEFTAIN
# 753    12  181215  BW1819    6    10        5   6         ALBERETTA
# 754    13  181215  BW1819    6    10        5   7    MADAME SULTANA
# ...

# %%
df['Trainer'].value_counts()
# Out:
# Sharat Kumar            127
# Neil Darashah           108
# B Prithviraj            100
# K Pradeep Annaiah        96
# Arjun Mangalorkar        95
# S Narredu                86
# S S Attaollahi           85
# Mahmood Khan             84
# S Inayathulla            80
# S Dominic                75
# Prasanna Kumar           73
# Irfan Ghatala            71
# M Rajendra Singh         67
# V Narayana Gowda         65
# Samar Singh              63
# Azhar Ali                62
# Darius Byramji           61
# V Lokanath               54
# Imtiaz Khan              53
# S Ganapathy              53
# Dheeraj Venkataswamy     48
# Faraz Arshad             47
# Neil B Devaney           45
# S Padmanabhan            45
# F Sirajuddin             43
# K P G Appu               41
# K Thomas                 39
# G Nityanand              38
# Praveen Jesu             36
# R V Manohar              33
# Hidayat Khan             32
# Warren Singh             31
# Rajesh Narredu           30
# ...

# %%
f = df['Trainer']=='M P Mahaesh'

# %%
df.loc[f]
# Out:
#       H.No    Date  Season  NoR  SRDN  Race No  Pl              Horse  \
# 74      10  181103  BW1819    7     2        2  10      ROCKET PUNCH
# 84       9  181103  BW1819    7     2        3  12        HONEY TRAP
# 101      2  181103  BW1819    7     2        5   9  GOOD TIME INDEED
# 378     11  181130  BW1819    7     6        1  11      ROCKET PUNCH
# 465      9  181201  BW1819    8     7        2   9        HONEY TRAP
# 605      1  181207  BW1819    8     8        7   6  GOOD TIME INDEED
# 939      2  181229  BW1819    8    13        2   2        HONEY TRAP
# 1172    12  190111  BW1819    8    15        7   8      ROCKET PUNCH
# 1268    11  190125  BW1819    8    17        1  10      ROCKET PUNCH
# 1292    12  190125  BW1819    8    17        3   W            VASUKI
# 1545     8  190208  BW1819    6    20        5   3        HONEY TRAP
# 1562     2  190209  BW1819    7    21        1  10            VASUKI
# 1772     4  190222  BW1819    9    23        7   5  GOOD TIME INDEED
# ...

# %%
df.dtypes
# Out:
# H.No                int64
# Date                int64
# Season             object
# NoR                 int64
# SRDN                int64
# Race No             int64
# Pl                 object
# Horse              object
# Pedigree           object
# Desc               object
# Trainer            object
# Jockey             object
# Wt                float64
# Al                 object
# Dr                float64
# Sh                 object
# Won By             object
# Dist Win          float64
# Rtg                object
# Odds               object
# Time               object
# Cup                object
# Classification     object
# Distance           object
# Unnamed: 24        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2189 entries, 0 to 2188
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   H.No            2189 non-null   int64
#  1   Date            2189 non-null   int64
#  2   Season          2189 non-null   object
#  3   NoR             2189 non-null   int64
#  4   SRDN            2189 non-null   int64
#  5   Race No         2189 non-null   int64
#  6   Pl              2189 non-null   object
#  7   Horse           2189 non-null   object
#  8   Pedigree        2189 non-null   object
#  9   Desc            2189 non-null   object
#  10  Trainer         2189 non-null   object
#  11  Jockey          2189 non-null   object
#  12  Wt              2189 non-null   float64
#  13  Al              544 non-null    object
#  14  Dr              2183 non-null   float64
#  15  Sh              2183 non-null   object
#  16  Won By          1892 non-null   object
# ...

# %%
df['Horse'].value_counts()
# Out:
# DESERT GOLD       9
# GRECIAN LIGHT     9
# BAZINGA           9
# ODYSSEY           9
# PRINCEAZEEM       9
#                  ..
# CRACK OF DAWN     1
# KAMBAKU           1
# CADILLAC SKY      1
# PERFECT KING      1
# ESTELLA           1
# Name: Horse, Length: 689, dtype: int64

# %%
f = df['Horse']=='GRECIAN LIGHT '

# %%
df[f]
# Out:
#       H.No    Date  Season  NoR  SRDN  Race No  Pl           Horse  \
# 196      3  181109  BW1819    8     3        7   9  GRECIAN LIGHT
# 494     10  181201  BW1819    8     7        4   5  GRECIAN LIGHT
# 583      8  181207  BW1819    8     8        4   7  GRECIAN LIGHT
# 906      4  181228  BW1819    7    12        6   7  GRECIAN LIGHT
# 1088     8  190105  BW1819    8    14        8   5  GRECIAN LIGHT
# 1253     8  190119  BW1819    7    16        7  10  GRECIAN LIGHT
# 1453     1  190201  BW1819    6    19        2   4  GRECIAN LIGHT
# 1785     5  190222  BW1819    9    23        8   6  GRECIAN LIGHT
# 2083     2  190322  BW1819    9    26        8   5  GRECIAN LIGHT
#
#                                Pedigree    Desc        Trainer  \
# 196   Win Legend(JPN)-Grecian Halo(USA)  5y b g   Hidayat Khan
# 494   Win Legend(JPN)-Grecian Halo(USA)  5y b g   Hidayat Khan
# 583   Win Legend(JPN)-Grecian Halo(USA)  5y b g  Irfan Ghatala
# ...

# %%
f = (df['Trainer']=='M P Mahaesh') | (df['Horse']=='GRECIAN LIGHT ')

# %%
df.loc[f]
# Out:
#       H.No    Date  Season  NoR  SRDN  Race No  Pl              Horse  \
# 74      10  181103  BW1819    7     2        2  10      ROCKET PUNCH
# 84       9  181103  BW1819    7     2        3  12        HONEY TRAP
# 101      2  181103  BW1819    7     2        5   9  GOOD TIME INDEED
# 196      3  181109  BW1819    8     3        7   9     GRECIAN LIGHT
# 378     11  181130  BW1819    7     6        1  11      ROCKET PUNCH
# 465      9  181201  BW1819    8     7        2   9        HONEY TRAP
# 494     10  181201  BW1819    8     7        4   5     GRECIAN LIGHT
# 583      8  181207  BW1819    8     8        4   7     GRECIAN LIGHT
# 605      1  181207  BW1819    8     8        7   6  GOOD TIME INDEED
# 906      4  181228  BW1819    7    12        6   7     GRECIAN LIGHT
# 939      2  181229  BW1819    8    13        2   2        HONEY TRAP
# 1088     8  190105  BW1819    8    14        8   5     GRECIAN LIGHT
# 1172    12  190111  BW1819    8    15        7   8      ROCKET PUNCH
# ...

# %%
df.loc[~f]
# Out:
#       H.No    Date  Season  NoR  SRDN  Race No  Pl                Horse  \
# 0        1  181102  BW1819    6     1        1   7          INKY BLACK
# 1        2  181102  BW1819    6     1        1   4         SHEER MAGIC
# 2        3  181102  BW1819    6     1        1   3         DESERT GILT
# 3        4  181102  BW1819    6     1        1   5              PURITY
# 4        5  181102  BW1819    6     1        1   2        TUDOR PRINCE
# ...    ...     ...     ...  ...   ...      ...  ..                  ...
# 2184     8  190323  BW1819    8    27        8   1              CAMILA
# 2185     9  190323  BW1819    8    27        8  10             GRANADA
# 2186    10  190323  BW1819    8    27        8   5   GREAT CELEBRATION
# 2187    11  190323  BW1819    8    27        8   9  EXTREMELYDANGEROUS
# 2188    12  190323  BW1819    8    27        8   7     JE NE SAIS QUOI
#
#                                           Pedigree       Desc  \
# ...

# %%
df['Trainer'].value_counts()
# Out:
# Sharat Kumar            127
# Neil Darashah           108
# B Prithviraj            100
# K Pradeep Annaiah        96
# Arjun Mangalorkar        95
# S Narredu                86
# S S Attaollahi           85
# Mahmood Khan             84
# S Inayathulla            80
# S Dominic                75
# Prasanna Kumar           73
# Irfan Ghatala            71
# M Rajendra Singh         67
# V Narayana Gowda         65
# Samar Singh              63
# Azhar Ali                62
# Darius Byramji           61
# V Lokanath               54
# Imtiaz Khan              53
# S Ganapathy              53
# Dheeraj Venkataswamy     48
# Faraz Arshad             47
# Neil B Devaney           45
# S Padmanabhan            45
# F Sirajuddin             43
# K P G Appu               41
# K Thomas                 39
# G Nityanand              38
# Praveen Jesu             36
# R V Manohar              33
# Hidayat Khan             32
# Warren Singh             31
# Rajesh Narredu           30
# ...

# %%
trainers = ['M P Mahaesh', 'P Shroff', 'Vishal Gaikwad', 'M Narredu', 'M Bobby']
f = df['Trainer'].isin(trainers)

# %%
df.loc[f]
# Out:
#       H.No    Date  Season  NoR  SRDN  Race No  Pl              Horse  \
# 74      10  181103  BW1819    7     2        2  10      ROCKET PUNCH
# 84       9  181103  BW1819    7     2        3  12        HONEY TRAP
# 101      2  181103  BW1819    7     2        5   9  GOOD TIME INDEED
# 378     11  181130  BW1819    7     6        1  11      ROCKET PUNCH
# 465      9  181201  BW1819    8     7        2   9        HONEY TRAP
# 512      3  181201  BW1819    8     7        6   7       HAMMERSMITH
# 515      6  181201  BW1819    8     7        6   1             OOMPH
# 605      1  181207  BW1819    8     8        7   6  GOOD TIME INDEED
# 739      7  181215  BW1819    6    10        4   9         SEA QUEST
# 741      9  181215  BW1819    6    10        4   3           VALEGRO
# 939      2  181229  BW1819    8    13        2   2        HONEY TRAP
# 1065     2  190105  BW1819    8    14        6   4       HAMMERSMITH
# 1172    12  190111  BW1819    8    15        7   8      ROCKET PUNCH
# ...

# %%
df.loc[f, 'Horse':'Trainer']
# Out:
#                   Horse                               Pedigree       Desc  \
# 74        ROCKET PUNCH      Mull Of Kintyre(USA)-Special Quest  5y dk b m
# 84          HONEY TRAP                 Top Class(USA)-Daniella     3y b f
# 101   GOOD TIME INDEED          Top Class(USA)-Good Time Sally     4y b h
# 378       ROCKET PUNCH      Mull Of Kintyre(USA)-Special Quest  5y dk b m
# 465         HONEY TRAP                 Top Class(USA)-Daniella     3y b f
# 512        HAMMERSMITH            Phoenix Tower(USA)-Samsa(FR)  3y dk b f
# 515              OOMPH   Midnight Interlude(USA)-Jahanara(IRE)     3y b f
# 605   GOOD TIME INDEED          Top Class(USA)-Good Time Sally     4y b h
# 739          SEA QUEST   Uncle Mo(USA)-Hungarian Boatbaby(USA)     3y b g
# 741            VALEGRO   Canford Cliffs(IRE)-Choice House(USA)     3y b c
# 939         HONEY TRAP                 Top Class(USA)-Daniella     3y b f
# 1065       HAMMERSMITH            Phoenix Tower(USA)-Samsa(FR)  4y dk b f
# ...

# %%
f = df['Horse'].str.contains('MAGIC', na=False)

# %%
df.loc[f]
# Out:
#       H.No    Date  Season  NoR  SRDN  Race No  Pl            Horse  \
# 1        2  181102  BW1819    6     1        1   4     SHEER MAGIC
# 169      3  181109  BW1819    8     3        4   3  ULTIMATE MAGIC
# 259      6  181117  BW1819    8     4        4  11      TURF MAGIC
# 328      1  181123  BW1819    6     5        3   4  ULTIMATE MAGIC
# 423      4  181130  BW1819    7     6        6   4     SHEER MAGIC
# 805      2  181220  BW1819    7    11        4   3  SIMPLY MAGICAL
# 850      2  181228  BW1819    7    12        1   4  SIMPLY MAGICAL
# 1056     3  190105  BW1819    8    14        5   9  ULTIMATE MAGIC
# 1167     7  190111  BW1819    8    15        7  10     SHEER MAGIC
# 1388     5  190126  BW1819    9    18        5  12  ULTIMATE MAGIC
# 1554     5  190208  BW1819    6    20        6   8     SHEER MAGIC
# 1656     7  190214  BW1819    7    22        3   3  SIMPLY MAGICAL
# 1773     5  190222  BW1819    9    23        7   8      TURF MAGIC
#
# ...

# %%
df.columns
# Out:
# Index(['H.No', 'Date', 'Season', 'NoR', 'SRDN', 'Race No', 'Pl', 'Horse',
#        'Pedigree', 'Desc', 'Trainer', 'Jockey', 'Wt', 'Al', 'Dr', 'Sh',
#        'Won By', 'Dist Win', 'Rtg', 'Odds', 'Time', 'Cup', 'Classification',
#        'Distance', 'Unnamed: 24'],
#       dtype='object')

# %%
df.rename(columns={'Horse':'horse'})
# Out:
#       H.No    Date  Season  NoR  SRDN  Race No  Pl                horse  \
# 0        1  181102  BW1819    6     1        1   7          INKY BLACK
# 1        2  181102  BW1819    6     1        1   4         SHEER MAGIC
# 2        3  181102  BW1819    6     1        1   3         DESERT GILT
# 3        4  181102  BW1819    6     1        1   5              PURITY
# 4        5  181102  BW1819    6     1        1   2        TUDOR PRINCE
# ...    ...     ...     ...  ...   ...      ...  ..                  ...
# 2184     8  190323  BW1819    8    27        8   1              CAMILA
# 2185     9  190323  BW1819    8    27        8  10             GRANADA
# 2186    10  190323  BW1819    8    27        8   5   GREAT CELEBRATION
# 2187    11  190323  BW1819    8    27        8   9  EXTREMELYDANGEROUS
# 2188    12  190323  BW1819    8    27        8   7     JE NE SAIS QUOI
#
#                                           Pedigree       Desc  \
# ...

# %%
df['Horse']
# Out:
# 0               INKY BLACK
# 1              SHEER MAGIC
# 2              DESERT GILT
# 3                   PURITY
# 4             TUDOR PRINCE
#                ...
# 2184                CAMILA
# 2185               GRANADA
# 2186     GREAT CELEBRATION
# 2187    EXTREMELYDANGEROUS
# 2188       JE NE SAIS QUOI
# Name: Horse, Length: 2189, dtype: object

# %%
df['Horse'] = df['Horse'].apply(str.strip)

# %%
f = df['Horse']=='GRECIAN LIGHT'

# %%
df.loc[f]
# Out:
#       H.No    Date  Season  NoR  SRDN  Race No  Pl          Horse  \
# 196      3  181109  BW1819    8     3        7   9  GRECIAN LIGHT
# 494     10  181201  BW1819    8     7        4   5  GRECIAN LIGHT
# 583      8  181207  BW1819    8     8        4   7  GRECIAN LIGHT
# 906      4  181228  BW1819    7    12        6   7  GRECIAN LIGHT
# 1088     8  190105  BW1819    8    14        8   5  GRECIAN LIGHT
# 1253     8  190119  BW1819    7    16        7  10  GRECIAN LIGHT
# 1453     1  190201  BW1819    6    19        2   4  GRECIAN LIGHT
# 1785     5  190222  BW1819    9    23        8   6  GRECIAN LIGHT
# 2083     2  190322  BW1819    9    26        8   5  GRECIAN LIGHT
#
#                                Pedigree    Desc        Trainer  \
# 196   Win Legend(JPN)-Grecian Halo(USA)  5y b g   Hidayat Khan
# 494   Win Legend(JPN)-Grecian Halo(USA)  5y b g   Hidayat Khan
# 583   Win Legend(JPN)-Grecian Halo(USA)  5y b g  Irfan Ghatala
# ...

# %%
df.drop(columns='Unnamed: 24', inplace=True)

# %%
df.columns
# Out:
# Index(['H.No', 'Date', 'Season', 'NoR', 'SRDN', 'Race No', 'Pl', 'Horse',
#        'Pedigree', 'Desc', 'Trainer', 'Jockey', 'Wt', 'Al', 'Dr', 'Sh',
#        'Won By', 'Dist Win', 'Rtg', 'Odds', 'Time', 'Cup', 'Classification',
#        'Distance'],
#       dtype='object')

# %%
df[['Age','Add_Desc']] = df['Desc'].str.split(n=1, expand = True)

# %%
df['Pl'].value_counts()
# Out:
# 3     203
# 2     202
# 1     202
# 4     201
# 5     200
# 6     198
# 7     190
# 8     185
# 9     165
# 10    146
# 11    126
# W      77
# 12     74
# 13     14
# 14      6
# Name: Pl, dtype: int64

# %%
filt = df['Pl'] =='W'
df.drop(index=df[filt].index, inplace=True)

# %%
df
# Out:
#       H.No    Date  Season  NoR  SRDN  Race No  Pl               Horse  \
# 0        1  181102  BW1819    6     1        1   7          INKY BLACK
# 1        2  181102  BW1819    6     1        1   4         SHEER MAGIC
# 2        3  181102  BW1819    6     1        1   3         DESERT GILT
# 3        4  181102  BW1819    6     1        1   5              PURITY
# 4        5  181102  BW1819    6     1        1   2        TUDOR PRINCE
# ...    ...     ...     ...  ...   ...      ...  ..                 ...
# 2184     8  190323  BW1819    8    27        8   1              CAMILA
# 2185     9  190323  BW1819    8    27        8  10             GRANADA
# 2186    10  190323  BW1819    8    27        8   5   GREAT CELEBRATION
# 2187    11  190323  BW1819    8    27        8   9  EXTREMELYDANGEROUS
# 2188    12  190323  BW1819    8    27        8   7     JE NE SAIS QUOI
#
#                                           Pedigree       Desc  \
# ...

# %%
df.nlargest(10,'Wt')
# Out:
#       H.No    Date  Season  NoR  SRDN  Race No  Pl             Horse  \
# 1149     1  190111  BW1819    8    15        6  11  ULTIMATE WARRIOR
# 360      1  181123  BW1819    6     5        6   1       SMILE STONE
# 983      1  181229  BW1819    8    13        6   2          SALAZAAR
# 499      1  181201  BW1819    8     7        5   8            AURIGA
# 814      1  181220  BW1819    7    11        5  12         BARACCHUS
# 1752     1  190222  BW1819    9    23        5  12         BARACCHUS
# 1150     2  190111  BW1819    8    15        6   8              RAFA
# 31       1  181102  BW1819    6     1        4   6          ACCOLADE
# 1229     1  190119  BW1819    7    16        5   6      BOLD COMMAND
# 414      1  181130  BW1819    7     6        5   5          ACCOLADE
#
#                                  Pedigree       Desc         Trainer  \
# 1149          Serious Spender(USA)-Arizza  5y dk b g      V Lokanath
# ...

# %%
df['Pl'] = df['Pl'].astype(int)

# %%
df['Odds'].value_counts()
# Out:
# 20        106
# 60         78
# 12         67
# 25         66
# 40         60
# 10         55
# 30         50
# 15         50
# 8          46
# 6          37
# 50         27
# 7          26
# 43505      18
# 4          18
# 43503      18
# 5          16
# 9          14
# 3          12
# 43572      12
# 43564      11
# 43507      11
# 43756      10
# 43501      10
# 43568       8
# 43566       8
# 43570       6
# 43751       6
# 43749       6
# 43574       5
# 43754       5
# 43752       5
# 2           3
# 43561       3
# 43744       3
# 43560       2
# 43746       2
# 1           2
# 43743       2
# 43757       2
# 43742       1
# 43745       1
# 45/100      1
# 43747       1
# 36/100      1
# 82/100      1
# 43497       1
# 43562       1
# 65/100      1
# 13          1
# Name: Odds, dtype: int64

# %%
place_grp=df.groupby(['Pl'])

# %%
place_grp.get_group(13)
# Out:
#       H.No    Date  Season  NoR  SRDN  Race No  Pl             Horse  \
# 447      5  181201  BW1819    8     7        1  13            AISHAH
# 460      4  181201  BW1819    8     7        2  13           BAIRAVA
# 492      8  181201  BW1819    8     7        4  13    PRINCESS HOLLY
# 520      3  181201  BW1819    8     7        7  13           LASSILO
# 534      3  181201  BW1819    8     7        8  13        KINGSFIELD
# 709      3  181215  BW1819    6    10        2  13          CULLINAN
# 749      8  181215  BW1819    6    10        5  13     SHAN BEN AARI
# 761      6  181215  BW1819    6    10        6  13         IRON FIST
# 1032     4  190105  BW1819    8    14        3  13         HIGH HAWK
# 1111    11  190111  BW1819    8    15        2  13       ABLE MASTER
# 1353     5  190126  BW1819    9    18        2  13      IRISH PRINCE
# 1383    14  190126  BW1819    9    18        4  13  TRULY DELIGHTFUL
# 1418    12  190126  BW1819    9    18        7  13         PLAY SAFE
# ...

# %%
place_grp['Odds'].value_counts(normalize = True).loc[13]
# Out:
# Odds
# 60    0.666667
# 25    0.166667
# 40    0.166667
# Name: Odds, dtype: float64

# %%
odds_grp = df.groupby(['Odds'])

# %%
odds_grp['Pl'].value_counts(normalize = True).head(20)
# Out:
# Odds  Pl
# 1     1     1.000000
# 2     1     1.000000
# 3     1     0.333333
#       2     0.250000
#       5     0.166667
#       3     0.083333
#       4     0.083333
#       6     0.083333
# 4     3     0.333333
#       4     0.222222
#       1     0.166667
#       2     0.166667
#       7     0.055556
#       9     0.055556
# 5     2     0.187500
#       3     0.187500
#       1     0.125000
#       6     0.125000
#       7     0.125000
#       4     0.062500
# Name: Pl, dtype: float64

# %%
odds_grp['Pl'].value_counts(normalize = True).loc[20]
# Out:
# Pl
# 4     0.150943
# 7     0.113208
# 8     0.113208
# 9     0.113208
# 3     0.103774
# 10    0.084906
# 6     0.075472
# 11    0.075472
# 5     0.066038
# 12    0.047170
# 1     0.028302
# 2     0.028302
# Name: Pl, dtype: float64

# %%
df.dropna(axis='index', how='any', subset=['Pl','Odds'])
# Out:
#       H.No    Date  Season  NoR  SRDN  Race No  Pl               Horse  \
# 0        1  181102  BW1819    6     1        1   7          INKY BLACK
# 1        2  181102  BW1819    6     1        1   4         SHEER MAGIC
# 2        3  181102  BW1819    6     1        1   3         DESERT GILT
# 3        4  181102  BW1819    6     1        1   5              PURITY
# 4        5  181102  BW1819    6     1        1   2        TUDOR PRINCE
# ...    ...     ...     ...  ...   ...      ...  ..                 ...
# 1003     6  181229  BW1819    8    13        8   4      INDIAN BRAHMOS
# 1004     7  181229  BW1819    8    13        8   2      COLOUR OF GOLD
# 1005     8  181229  BW1819    8    13        8   3         PRINCEAZEEM
# 1006     9  181229  BW1819    8    13        8   6            FIORENZO
# 1007    10  181229  BW1819    8    13        8   8  AS GOOD AS IT GETS
#
#                                           Pedigree       Desc  \
# ...

# %%
df['Age']
# Out:
# 0       4y
# 1       4y
# 2       6y
# 3       4y
# 4       5y
#         ..
# 2184    4y
# 2185    7y
# 2186    4y
# 2187    7y
# 2188    4y
# Name: Age, Length: 2112, dtype: object

# %%
df['Age']= df['Age'].str.strip('y').astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2112 entries, 0 to 2188
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   H.No            2112 non-null   int64
#  1   Date            2112 non-null   int64
#  2   Season          2112 non-null   object
#  3   NoR             2112 non-null   int64
#  4   SRDN            2112 non-null   int64
#  5   Race No         2112 non-null   int64
#  6   Pl              2112 non-null   int32
#  7   Horse           2112 non-null   object
#  8   Pedigree        2112 non-null   object
#  9   Desc            2112 non-null   object
#  10  Trainer         2112 non-null   object
#  11  Jockey          2112 non-null   object
#  12  Wt              2112 non-null   float64
#  13  Al              524 non-null    object
#  14  Dr              2112 non-null   float64
#  15  Sh              2112 non-null   object
#  16  Won By          1892 non-null   object
# ...

# %%
place_grp['Age'].mean()
# Out:
# Pl
# 1     4.262376
# 2     4.465347
# 3     4.546798
# 4     4.756219
# 5     4.835000
# 6     4.797980
# 7     5.047368
# 8     4.989189
# 9     5.145455
# 10    5.041096
# 11    5.039683
# 12    5.189189
# 13    5.000000
# 14    4.333333
# Name: Age, dtype: float64

# %%
place_grp['Age'].median()
# Out:
# Pl
# 1     4.0
# 2     4.0
# 3     4.0
# 4     5.0
# 5     5.0
# 6     5.0
# 7     5.0
# 8     5.0
# 9     5.0
# 10    5.0
# 11    5.0
# 12    5.0
# 13    5.0
# 14    4.5
# Name: Age, dtype: float64
