# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.concat(pd.read_excel(r'C:\Users\Testing\ALL CENTRES-DATA 210122.xlsx', sheet_name=None), ignore_index=True)

# %%
print([l for l in df.columns])
# Out:
# ['Centre', 'Season', 'Season Race Day', 'Date', 'NoR', 'RACE TIME', 'CUP', 'CLASSIFICATION', 'DISTANCE', 'Race No', 'NoH', 'Result', 'Horse No', 'Horse', 'Pedigree', 'Desc', 'Age', 'Trainer', 'Jockey', 'Wt', 'Al', 'Dr', 'Sh', 'Won By', 'Dist Win', 'Rtg', 'Odds', 'Time', 'TurfBee', 'BOL', 'Dina Thanthi', 'Experts', 'Media Man', 'S. Today', 'TRS', 'Telegraph', 'BNG', 'Telangana Today', 'Telangana Times', 'Andhra Jyothi', 'Asian Age', 'Times of India', 'The Hindu', 'Mumbai Mirror', 'Deccan Herald', 'Opening Odds', 'OOF', 'Latest Odds', 'LOF', 'Middle Odds', 'MOF', 'Final Odds', 'FOF', 'Odds Trend', 'BLR Tote Win', 'BLR Tote Win-Plc', 'BLR Tote SHP', 'BLR Tote SHP-Plc', 'BLR Tote THP', 'BLR Tote THP-Plc', 'HYD Tote Win', 'HYD Tote Win-Plc', 'HYD Tote SHP', 'HYD Tote SHP-Plc', 'HYD Tote THP', 'HYD Tote THP-Plc', 'KOL Tote Win', 'KOL  Tote Win-Plc', 'KOL  Tote SHP', 'KOL  Tote SHP-Plc', 'KOL Tote THP', 'KOL Tote THP-Plc', 'MYS Tote Win', 'MYS Tote Win-Plc', 'MYS Tote SHP', 'MYS Tote SHP-Pl
# ...

# %%
df.drop(columns=[ 'Season Race Day', 'CUP', 'NoH', 'Pedigree', 'Desc', 'Wt', 'Al',  'Sh', 'Won By',
                 'Dist Win','Rtg', 'Odds', 'Time','BLR Tote Win', 'BLR Tote Win-Plc', 'BLR Tote SHP',
                 'BLR Tote SHP-Plc', 'BLR Tote THP', 'BLR Tote THP-Plc', 'HYD Tote Win', 'HYD Tote Win-Plc',
                 'HYD Tote SHP', 'HYD Tote SHP-Plc', 'HYD Tote THP', 'HYD Tote THP-Plc', 'KOL Tote Win',
                 'KOL  Tote Win-Plc', 'KOL  Tote SHP', 'KOL  Tote SHP-Plc', 'KOL Tote THP', 'KOL Tote THP-Plc',
                 'MYS Tote Win', 'MYS Tote Win-Plc', 'MYS Tote SHP', 'MYS Tote SHP-Plc', 'MYS Tote THP',
                 'MYS Tote THP-Plc', 'MUM Tote Win', 'MUM Tote Win-Plc', 'MUM Tote SHP', 'MUM Tote SHP-Plc',
                 'MUM Tote THP', 'MUM Tote THP-Plc', 'PUN Tote Win', 'PUN Tote Win-Plc', 'PUN Tote SHP',
                 'PUN Tote SHP-Plc', 'PUN Tote THP', 'PUN Tote THP-Plc', 'C Tote Win', 'C Tote Win-Plc',
                 'C Tote SHP', 'C Tote SHP-Plc', 'C Tote THP', 'C Tote THP-Plc', 'Unnamed: 96', 'Unnamed: 97',
                 'Unnamed: 98', 'Unnamed: 99', 'Unnamed: 100'], inplace=True)

# %%
df['Age'] = [x.strip('y') for x in df['Age']]
df['Age'] = pd.to_numeric(df['Age'])
df['Age'].unique()
# Out:
# array([ 4,  6,  5,  8,  3,  7,  2,  9, 11, 10, 12], dtype=int64)

# %%
df.rename(columns = {'CLASSIFICATION':'Classification', 'DISTANCE':'Distance', 'Opening Odds':'OPEN', 'Latest Odds':'LATEST',
                     'Middle Odds':'MIDDLE', 'Final Odds':'FINAL', 'OOF':'OO', 'LOF':'LO', 'MOF':'MO', 'FOF':'FO', 'Result':'Pl'
                    }, inplace = True)

# %%
df.columns
# Out:
# Index(['Centre', 'Season', 'Date', 'NoR', 'RACE TIME', 'Classification',
#        'Distance', 'Race No', 'Pl', 'Horse No', 'Horse', 'Age', 'Trainer',
#        'Jockey', 'Dr', 'TurfBee', 'BOL', 'Dina Thanthi', 'Experts',
#        'Media Man', 'S. Today', 'TRS', 'Telegraph', 'BNG', 'Telangana Today',
#        'Telangana Times', 'Andhra Jyothi', 'Asian Age', 'Times of India',
#        'The Hindu', 'Mumbai Mirror', 'Deccan Herald', 'OPEN', 'OO', 'LATEST',
#        'LO', 'MIDDLE', 'MO', 'FINAL', 'FO', 'Odds Trend'],
#       dtype='object')

# %%
df['RACE TIME'].unique()
# Out:
# array([datetime.time(14, 45), datetime.time(15, 15),
#        datetime.time(15, 45), datetime.time(16, 15),
#        datetime.time(16, 45), datetime.time(17, 15),
#        datetime.time(14, 15), datetime.time(13, 45),
#        datetime.time(14, 20), datetime.time(14, 55),
#        datetime.time(15, 30), datetime.time(16, 5), datetime.time(16, 40),
#        datetime.time(13, 15), datetime.time(15, 20),
#        datetime.time(15, 55), datetime.time(16, 30),
#        datetime.time(17, 10), datetime.time(17, 50),
#        datetime.time(18, 15), datetime.time(17, 45),
#        datetime.time(13, 30), datetime.time(14, 0), datetime.time(14, 30),
#        datetime.time(15, 0), datetime.time(16, 0), datetime.time(17, 0),
#        datetime.time(17, 30), datetime.time(14, 35),
#        datetime.time(15, 10), datetime.time(16, 20),
#        datetime.time(16, 55), datetime.time(15, 5), datetime.time(15, 40),
#        datetime.time(16, 50), datetime.time(17, 25), datetime.time(13, 0),
# ...

# %%
df.Season.replace(190222, 'BW1819', inplace=True)
df.Dr.replace([np.nan,'-','3?', '2?', '6?', '1?', '4?', '5?', '10?', '8?', '9?',
       '7?', '14?', '12?', '11?', '13?', '5 h'], [0,0,3,2,6,1,4,5,10,8,9,7,14,12,11,13,5], inplace = True)
df.replace([' F1', 'F1 ', ' F2', 'F2 ', ' F3', 'F3 ', ' F4', 'F4 ', ' F5', 'F5 ', ' F6', 'F6 ', ' F7', 'F7 ', ' F8', 'F8 ', ' F9', 'F9 ', ' F10', 'F10 ', ' F11', 'F11 ', ' F12', 'F12 ', ' F13', 'F13 ', ' F14', 'F14 ', ' F15', 'F15 '], ['F1', 'F1', 'F2', 'F2', 'F3', 'F3', 'F4', 'F4', 'F5', 'F5', 'F6', 'F6', 'F7', 'F7', 'F8', 'F8', 'F9', 'F9', 'F10', 'F10', 'F11', 'F11', 'F12', 'F12', 'F13', 'F13', 'F14', 'F14', 'F15', 'F15'], inplace=True)
df.Pl.replace(['w', 'W', 'NC'], [0, 0, 0], inplace=True)

# %%
df.OPEN.replace(['NO',' '],[np.nan, np.nan],inplace=True)
df.OO.replace(['NO',np.nan],['F0', 'F0'],inplace=True)
df.LATEST.replace(['NO',' ','N0'],[np.nan, np.nan, np.nan],inplace=True)
df.LO.replace(['NO',np.nan],['F0', 'F0'],inplace=True)
df.MIDDLE.replace(['NO',' ','N0'],[np.nan, np.nan, np.nan],inplace=True)
df.MO.replace(['NO',np.nan,'F66'],['F0','F0', 'F0'],inplace=True)
df.FINAL.replace(['NO',' ','N0'],[np.nan, np.nan, np.nan],inplace=True)
df.FO.replace(['NO',np.nan,'F100'],['F0','F0', 'F0'],inplace=True)

# %%
df['TurfBee'].replace([' ','.','9-','f',1,' F',2,3,' T'], [np.nan,np.nan,np.nan,'F','F','F','S','T','T'], inplace=True)
df['BOL'].replace([' ','.','9-','f',1,' F',2,3,' T'], [np.nan,np.nan,np.nan,'F','F','F','S','T','T'], inplace=True)
df['Dina Thanthi'].replace([0,' ','.','9-','f',1,' F',2,3,' T'], [np.nan,np.nan,np.nan,np.nan,'F','F','F','S','T','T'], inplace=True)
df['Experts'].replace([0,' ','.','9-','f',1,' F',2,3,' T'], [np.nan,np.nan,np.nan,np.nan,'F','F','F','S','T','T'], inplace=True)
df['Media Man'].replace(['A','   ','  ',0,' ','.','9-','f',1,' F',2,3,' T'], [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,'F','F','F','S','T','T'], inplace=True)
df['S. Today'].replace([4,'A','   ','  ',0,' ','.','9-','f',1,' F',2,' S',3,' T'], [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,'F','F','F','S','S','T','T'], inplace=True)
df['TRS'].replace([4,'A','   ','  ',0,' ','.','9-','f',1,' F',2,' S',3,' T'], [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,'F','F','F','S','S','T','T'], inplace=True)
df['Telegraph'].replace([5,4,'A','   ','  ',0,' ','.','9-','f',1,' F',2,' S',3,' T'], [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,'F','F','F','S','S','T','T'], inplace=True)
df['BNG'].replace([5,4,'A','   ','  ',0,' ','.','9-','f',1,' F',2,' S',3,' T'], [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,'F','F','F','S','S','T','T'], inplace=True)
df['Telangana Today'].replace([5,4,'A','   ','  ',0,' ','.','9-','f',1,' F',2,' S',3,' T'], [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,'F','F','F','S','S','T','T'], inplace=True)
df['Telangana Times'].replace([6, 7, 8, 9, 10, 11, 12,5,4,'A','   ','  ',0,' ','.','9-','f',1,' F',2,' S',3,' T'], [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,'F','F','F','S','S','T','T'], inplace=True)
df['Andhra Jyothi'].replace([6, 7, 8, 9, 10, 11, 12,5,4,'A','   ','  ',0,' ','.','9-','f',1,' F',2,' S',3,' T'], [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,'F','F','F','S','S','T','T'], inplace=True)
df['Asian Age'].replace([6, 7, 8, 9, 10, 11, 12,5,4,'A','   ','  ',0,' ','.','9-','f',1,' F',2,' S',3,' T'], [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,'F','F','F','S','S','T','T'], inplace=True)
df['Times of India'].replace([6, 7, 8, 9, 10, 11, 12,5,4,'A','   ','  ',0,' ','.','9-','f',1,' F',2,' S',3,' T'], [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,'F','F','F','S','S','T','T'], inplace=True)
df['The Hindu'].replace([6, 7, 8, 9, 10, 11, 12,5,4,'A','   ','  ',0,' ','.','9-','f',1,' F',2,' S',3,' T'], [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,'F','F','F','S','S','T','T'], inplace=True)
df['Mumbai Mirror'].replace([6, 7, 8, 9, 10, 11, 12,5,4,'A','   ','  ',0,' ','.','9-','f',1,' F',2,' S',3,' T'], [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,'F','F','F','S','S','T','T'], inplace=True)
df['Deccan Herald'].replace([6, 7, 8, 9, 10, 11, 12,5,4,'A','   ','  ',0,' ','.','9-','f',1,' F',2,' S',3,' T'], [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,'F','F','F','S','S','T','T'], inplace=True)

# %%
df['Horse'].unique()
# Out:
# array(['INKY BLACK ', 'SHEER MAGIC ', 'DESERT GILT ', ..., 'QUEENSHIP ',
#        'MADELEINE ', 'CHUTZPAH '], dtype=object)

# %%
df['Distance'].value_counts()
# Out:
# 1200    11761
# 1400     8934
# 1600     4402
# 1100     3247
# 1000     2194
# 2000      935
# 1800      698
# 2400      424
# 2800       56
# 2200       34
# 3000       24
# 3200        8
# 1500        5
# Name: Distance, dtype: int64

# %%
df.Distance.replace(1500, 1600, inplace=True)

# %%
blrdf = df.loc[df['Centre']=='BLR']

# %%
blrdf
# Out:
#      Centre Season    Date  NoR RACE TIME                 Classification  \
# 0       BLR   BW18  181102    6  14:45:00                       00 TO 20
# 1       BLR   BW18  181102    6  14:45:00                       00 TO 20
# 2       BLR   BW18  181102    6  14:45:00                       00 TO 20
# 3       BLR   BW18  181102    6  14:45:00                       00 TO 20
# 4       BLR   BW18  181102    6  14:45:00                       00 TO 20
# ...     ...    ...     ...  ...       ...                            ...
# 5810    BLR   BW19  200306    9  17:15:00  15 TO 35 (5 YRS OLD & UPWARD)
# 5811    BLR   BW19  200306    9  17:15:00  15 TO 35 (5 YRS OLD & UPWARD)
# 5812    BLR   BW19  200306    9  17:15:00  15 TO 35 (5 YRS OLD & UPWARD)
# 5813    BLR   BW19  200306    9  17:15:00  15 TO 35 (5 YRS OLD & UPWARD)
# 5814    BLR   BW19  200306    9  17:15:00  15 TO 35 (5 YRS OLD & UPWARD)
#
#       Distance  Race No  Pl  Horse No           Horse  Age            Trainer  \
# ...

# %%
paper = 'Asian Age'

# %%
paper_df = blrdf[['Season', 'Date', 'Race No', 'Pl', paper]].copy()
paper_df
# Out:
#      Season    Date  Race No  Pl Asian Age
# 0      BW18  181102        1   7       NaN
# 1      BW18  181102        1   4       NaN
# 2      BW18  181102        1   3       NaN
# 3      BW18  181102        1   5       NaN
# 4      BW18  181102        1   2       NaN
# ...     ...     ...      ...  ..       ...
# 5810   BW19  200306        9   7       NaN
# 5811   BW19  200306        9  11       NaN
# 5812   BW19  200306        9   5       NaN
# 5813   BW19  200306        9   2       NaN
# 5814   BW19  200306        9   3       NaN
#
# [5815 rows x 5 columns]

# %%
if not paper_df[paper].isnull().all().all():
    paper_df['num_pred']=paper_df[paper].replace(['F','S','T'],[1,2,3])
else:
    paper_df['num_pred']=paper_df[paper]
paper_df.dropna(inplace=True)
paper_df['num_pred'] = paper_df['num_pred'].astype(int)
paper_df['check_res'] = list(zip(paper_df.num_pred, paper_df.Pl))
paper_df
# Out:
#      Season    Date  Race No  Pl Asian Age  num_pred check_res
# 745    BW18  181215        5   2         S         2    (2, 2)
# 746    BW18  181215        5   1         F         1    (1, 1)
# 1549   BW18  190208        5  11         S         2   (2, 11)

# %%
combo=[(1, 1),(1, 2),(1, 3),(2, 1),(2, 2),(2, 3),(3, 1),(3, 2),(3, 3)]
race_stats = paper_df.groupby(["Season","Date", "Race No", "check_res"], as_index=True).size().unstack(fill_value=0)
mis_col = [i for i in combo if i not in race_stats.columns]
for col in mis_col:
#     print(col)
    race_stats["{}".format(col)] = [0] * len(race_stats)
    
for n,col in enumerate(race_stats.columns):
    if type(col) is not tuple:
        print(tuple(map(int, col[1:-1].split(', '))))
        print(race_stats.columns[n])
        race_stats.rename(columns={col: tuple(map(int, col[1:-1].split(', ')))}, inplace=True)
# race_stats = race_stats[combo]
race_stats
# Out:
# (1, 2)
# (1, 2)
# (1, 3)
# (1, 3)
# (2, 1)
# (2, 1)
# (2, 3)
# (2, 3)
# (3, 1)
# (3, 1)
# (3, 2)
# (3, 2)
# (3, 3)
# (3, 3)
# check_res              (1, 1)  (2, 2)  (2, 11)  (1, 2)  (1, 3)  (2, 1)  \
# Season Date   Race No
# BW18   181215 5             1       1        0       0       0       0
#        190208 5             0       0        1       0       0       0
#
# check_res              (2, 3)  (3, 1)  (3, 2)  (3, 3)
# Season Date   Race No
# BW18   181215 5             0       0       0       0
#        190208 5             0       0       0       0

# %%
race_stats.reset_index(inplace=True)

# race_stats[(1,1)].replace(1,'F/W', inplace=True)
race_stats[(2,1)].replace(1,2, inplace=True)
race_stats[(3,1)].replace(1,3, inplace=True)

race_stats['final']=race_stats[(1,1)] + race_stats[(2,1)] + race_stats[(3,1)]
race_stats['final'].replace([0,1,2,3],['L','F/W','S/W','T/W'], inplace=True)

race_stats
# Out:
# check_res Season    Date  Race No  (1, 1)  (2, 2)  (2, 11)  (1, 2)  (1, 3)  \
# 0           BW18  181215        5       1       1        0       0       0
# 1           BW18  190208        5       0       0        1       0       0
#
# check_res  (2, 1)  (2, 3)  (3, 1)  (3, 2)  (3, 3) final
# 0               0       0       0       0       0   F/W
# 1               0       0       0       0       0     L

# %%
for i in race_stats.columns:
    if type(i) is tuple:
        race_stats[i].replace([2,3,4,5],[1,1,1,1], inplace=True)

# %%
race_stats['one'] = [0] * len(race_stats)
race_stats['two'] = [0] * len(race_stats)
race_stats['three'] = [0] * len(race_stats)
for i in race_stats.columns:
    if i[0] == 3:
        race_stats['three'] = race_stats['three'] | race_stats[i[0],i[1]]
    elif i[0] == 2:
        race_stats['two'] = race_stats['two'] | race_stats[i[0],i[1]]
    elif i[0] == 1:
        race_stats['one'] = race_stats['one'] | race_stats[i[0],i[1]]

# %%
overall_media_race_stats= race_stats
overall_media_race_stats
# Out:
# check_res Season    Date  Race No  (1, 1)  (2, 2)  (2, 11)  (1, 2)  (1, 3)  \
# 0           BW18  181215        5       1       1        0       0       0
# 1           BW18  190208        5       0       0        1       0       0
#
# check_res  (2, 1)  (2, 3)  (3, 1)  (3, 2)  (3, 3) final  one  two  three
# 0               0       0       0       0       0   F/W    1    1      0
# 1               0       0       0       0       0     L    0    1      0

# %%
try: 
    print(round((overall_media_race_stats['final'].value_counts().get('T/W',0)/overall_media_race_stats['three'].value_counts().get(1,0))*100,2))
except:
    print(0)
# Out:
# 0

# %%
race_stats['final'].value_counts(normalize=True)
# Out:
# L      0.5
# F/W    0.5
# Name: final, dtype: float64

# %%
from collections import defaultdict

# %%
media_list = ['TurfBee', 'BOL', 'Dina Thanthi', 'Experts', 'Media Man',
       'S. Today', 'TRS', 'Telegraph', 'BNG', 'Telangana Today',
       'Telangana Times', 'Andhra Jyothi', 'Asian Age', 'Times of India',
       'The Hindu', 'Mumbai Mirror', 'Deccan Herald']
dicts = defaultdict(dict)
for m in media_list:
    race=0
    for i in ['F', 'S', 'T']:
        temp = blrdf[blrdf[m]==i]
        if len(temp) == 0:
            # print(m)
            continue
        if len(temp) > race:
            dicts[m]['TR'] = len(temp)
            race = len(temp)
        dicts[m][i] = round(100*len(temp.loc[temp["Pl"]==1])/len(temp), 2)

media_df = pd.DataFrame.from_dict(dicts, 'index')
media_df
# Out:
#                   TR       F      S      T
# TurfBee          533   33.96  20.53  13.85
# BOL              545   31.12  20.92  14.53
# Dina Thanthi     544   32.16  19.49  14.63
# Experts          536   34.21  21.46  13.25
# Media Man        534   33.96  18.61  10.67
# S. Today         539   20.07  26.53  10.95
# TRS              541   28.28  21.04  17.47
# Telegraph        301   30.33  20.93  14.24
# BNG                7   57.14   0.00  28.57
# Telangana Today  110   36.36  10.00  10.19
# Telangana Times    7   42.86  14.29  14.29
# Asian Age          2  100.00   0.00    NaN
# Times of India   523   33.27  22.44  23.53
# The Hindu        113   36.28  20.54  15.15
# Mumbai Mirror     38   31.58  26.32  10.53
# Deccan Herald    296   33.56  22.97  16.84

# %%
media_df['T'].get('Andhra Jyothi', np.nan)
# Out:
# nan

# %%
dff = blrdf.loc[blrdf['Trainer']=='Arjun Mangalorkar']

# %%
edge_for_win = [round((dff.loc[dff['Pl'] == 1]['OPEN'].mean()*((len(dff.loc[dff['Pl'] == 1]) / len(dff)) * 100)-(100 - ((len(dff.loc[dff['Pl'] == 1]) / len(dff)) * 100))), 2),
                    round((dff.loc[dff['Pl'] == 1]['LATEST'].mean()*((len(dff.loc[dff['Pl'] == 1]) / len(dff)) * 100)-(100 - ((len(dff.loc[dff['Pl'] == 1]) / len(dff)) * 100))),2),
                    round((dff.loc[dff['Pl'] == 1]['MIDDLE'].mean()*((len(dff.loc[dff['Pl'] == 1]) / len(dff)) * 100)-(100 - ((len(dff.loc[dff['Pl'] == 1]) / len(dff)) * 100))),2),
                    round((dff.loc[dff['Pl'] == 1]['FINAL'].mean()*((len(dff.loc[dff['Pl'] == 1]) / len(dff)) * 100)-(100 - ((len(dff.loc[dff['Pl'] == 1]) / len(dff)) * 100))),2)]

# %%
import math
edge_for_win = ['No wins' if math.isnan(x) else x for x in edge_for_win]

# %%
edge_for_win
# Out:
# [-29.99, -22.79, -27.9, -24.87]

# %%
(len(dff.loc[dff['Pl'] == 1]) / len(dff)) * 100
# Out:
# 13.718411552346572

# %%
dff.loc[dff['Pl'] == 1]
# Out:
#      Centre Season    Date  NoR RACE TIME                  Classification  \
# 88      BLR   BW18  181103    7  15:45:00        (3 YRS OLD MAIDENS ONLY)
# 167     BLR   BW18  181109    8  15:15:00  30 TO 50 ( 4 YRS OLD & UPWARD)
# 380     BLR   BW18  181130    7  14:45:00   15 TO 35 (4 YRS OLD & UPWARD)
# 478     BLR   BW18  181201    8  14:45:00                        15 TO 35
# 565     BLR   BW18  181207    8  14:45:00                        15 TO 35
# 584     BLR   BW18  181207    8  15:15:00              4 YRS OLD & UPWARD
# 915     BLR   BW18  181228    7  17:15:00                        15 TO 35
# 1068    BLR   BW18  190105    8  16:15:00               ( 4 YRS OLD ONLY)
# 1302    BLR   BW18  190125    8  15:15:00                        30 TO 50
# 1368    BLR   BW18  190126    9  14:15:00                      60 - ABOVE
# 1495    BLR   BW18  190201    6  17:15:00                        15 TO 35
# 1747    BLR   BW18  190222    9  15:15:00        (3 YRS OLD MAIDENS ONLY)
# ...
